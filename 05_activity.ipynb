# %% [markdown]
# <a href="https://colab.research.google.com/github/egynzhu-personal/siop-python-seminar-2024/blob/main/05_activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Activity
# ## In this activity you will
# - Train a machine learning model to predict turnover on IBM's dataset
# - Evaluate its performance
# ## We will build on some skills leveraged throughout the course including:
# 1. Data manipulation in Pandas
# 2. Conditionals (if statements)
# 3. Machine Learning
# 4. OOP (Bonus)
# 5. Visualization (Bonus)

# %%
import pandas as pd

# !wget attrition.csv https://github.com/egynzhu-personal/siop-python-seminar-2024/raw/main/data/WA_Fn-UseC_-HR-Employee-Attrition.csv

df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
# --2024-04-17 18:46:31--  http://attrition.csv/
# Resolving attrition.csv (attrition.csv)... failed: Name or service not known.
# wget: unable to resolve host address ‘attrition.csv’
# --2024-04-17 18:46:31--  https://github.com/egynzhu-personal/siop-python-seminar-2024/raw/main/data/WA_Fn-UseC_-HR-Employee-Attrition.csv
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/egynzhu-personal/siop-python-seminar-2024/main/data/WA_Fn-UseC_-HR-Employee-Attrition.csv [following]
# --2024-04-17 18:46:31--  https://raw.githubusercontent.com/egynzhu-personal/siop-python-seminar-2024/main/data/WA_Fn-UseC_-HR-Employee-Attrition.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %% [markdown]
# ## Recommended Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Below are function docstrings to help guide you through the activity
# - You may utilize them, tweak them, or code your own if you would like

# %% [markdown]
# ## Remove Missing Data
# - Include a conditional!
# - If there is no missing data, then just return the dataframe

# %%
def remove_missing_rows(df):
    """
    Remove rows with missing values from the DataFrame.

    Parameters:
    df (DataFrame): Input DataFrame with potential missing values.

    Returns:
    DataFrame: DataFrame with missing rows removed.
    """
    pass

# %% [markdown]
# ## Train test split

# %%
def train_test_split_data(df, target_col, test_size=0.2, random_state=42):
    """
    Split the data into training and test sets.

    Parameters:
    df (DataFrame): Input DataFrame.
    target_col (str): Name of the target column.
    test_size (float): Proportion of the dataset to include in the test split.
    random_state (int): Random state for reproducibility.

    Returns:
    tuple: (X_train, X_test, y_train, y_test)
    """
    pass

# %% [markdown]
# ## One hot encoding of categorical features

# %%
def one_hot_encode(df, columns_to_encode):
    """
    Perform one-hot encoding on specified columns in the DataFrame.

    Parameters:
    df (DataFrame): Input DataFrame.
    columns_to_encode (list): List of column names to encode.

    Returns:
    DataFrame: DataFrame with one-hot encoded columns.
    """
    pass

# %% [markdown]
# ## Fit and Evaluate Model

# %%
def fit_evaluate_model(model, X_train, X_test, y_train, y_test):
    """
    Fit a given model and evaluate its performance.

    Parameters:
    model: Machine learning model instance.
    X_train (DataFrame): Training features.
    X_test (DataFrame): Test features.
    y_train (Series): Training target.
    y_test (Series): Test target.

    Returns:
    dict: Classification report.
    """
    pass

# %% [markdown]
# ## Example Code Usage

# %%
# Example usage:
# Load the dataset
# df = pd.read_csv('ibm_employee_attrition.csv')

# Remove missing rows
# df_clean = remove_missing_rows(df)

# Train-test split
# X_train, X_test, y_train, y_test = train_test_split_data(df_clean, 'Attrition')

# One-hot encode categorical columns
# categorical_cols = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# X_train_encoded = one_hot_encode(X_train, categorical_cols)
# X_test_encoded = one_hot_encode(X_test, categorical_cols)

# Instantiate DecisionTreeClassifier
# model = DecisionTreeClassifier(random_state=42)

# Fit and evaluate model
# report = fit_evaluate_model(model, X_train_encoded, X_test_encoded, y_train, y_test)
# print(report)

# %% [markdown]
# ## Bonus!
# - Create a class that:
# 1. removes missing rows
# 2. one hot encodes categorical cols
#
# Recommended init:
# - categorical columns

# %%
# Example usage:
# data_preprocessor = DataPreprocessor(categorical_cols=['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime'])
# df_clean = data_preprocessor.remove_missing_rows(df)
# df_encoded = data_preprocessor.one_hot_encode(df_clean)

# %% [markdown]
# # Bonus #2
# 1. Visualize Model Performance
# - Recommended Approach: Use matplotlib to plot the classification report
